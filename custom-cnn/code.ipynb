# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
kagglehub.competition_download('aptos2019-blindness-detection')
# Out:
# Downloading from https://www.kaggle.com/api/v1/competitions/data/download-all/aptos2019-blindness-detection...
# 100%|██████████| 9.51G/9.51G [02:00<00:00, 85.1MB/s]
# Extracting files...
# '/root/.cache/kagglehub/competitions/aptos2019-blindness-detection'

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import random
import sklearn
from sklearn.model_selection import train_test_split
import seaborn as sns

# Seeds
TRAIN_TEST_SPLIT_SEED = 564258
TRAIN_VAL_SPLIT_SEED = 123456

# Config
TEST_PERCENT = 0.2
VAL_PERCENT = 0.2

# File paths
BASEDIR = '/root/.cache/kagglehub/competitions/aptos2019-blindness-detection'
IMAGESDIR = f'{BASEDIR}/train_images'

# All labels
labels_df = pd.read_csv(f'{BASEDIR}/train.csv')
labels_df = labels_df.set_index('id_code')
labels_df.head()
# Out:
#               diagnosis
# id_code
# 000c1434d8d7          2
# 001639a390f0          4
# 0024cdab0c1e          1
# 002c21358ce6          0
# 005b95c28852          0

# %%
train_labels_df, test_labels_df = train_test_split(labels_df, test_size=TEST_PERCENT, random_state=TRAIN_TEST_SPLIT_SEED, stratify=labels_df['diagnosis'])
print(f'Number of train instances: {len(train_labels_df)}')
print(f'Number of test instances: {len(test_labels_df)}')
train_labels_df.to_csv(f'train_labels.csv')
test_labels_df.to_csv(f'test_labels.csv')
# Out:
# Number of train instances: 2929
# Number of test instances: 733

# %%
# y distribution
y_dist_train = train_labels_df['diagnosis'].value_counts().sort_index()
y_dist_test = test_labels_df['diagnosis'].value_counts().sort_index()
print('y distribution (train):', y_dist_train)
print('y distribution (test):', y_dist_test)

# plot distributions
combined_y_dist = pd.DataFrame({'train': y_dist_train, 'test': y_dist_test})
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
combined_y_dist.plot(kind='bar', stacked=False, ax=ax, title='Distribution of diagnoses (train and test)', rot=0)
ax.set_ylabel('Number of instances')
plt.show()
# Out:
# y distribution (train): diagnosis
# 0    1444
# 1     296
# 2     799
# 3     154
# 4     236
# Name: count, dtype: int64
# y distribution (test): diagnosis
# 0    361
# 1     74
# 2    200
# 3     39
# 4     59
# Name: count, dtype: int64

# %%
from tensorflow import keras

# Global Parameters
IMG_SIZE = 224
BATCH_SIZE = 32
LEARNING_RATE = 0.001
NUM_EPOCHS = 100
PATIENCE = 8
SEEDS = [564258, 564307, 564322]
NUM_CLASSES = 5

# %%
# Preprocessing & Augmentation
def get_data_augmentation(seed):
    return keras.models.Sequential([
        keras.layers.RandomFlip("horizontal", seed=seed),
        keras.layers.RandomRotation(0.05, seed=seed),
        keras.layers.RandomZoom(height_factor=(-0.2, 0.1), seed=seed),
        keras.layers.RandomBrightness(factor=0.15, seed=seed),
        keras.layers.RandomContrast(factor=0.15, seed=seed)
    ], name="data_augmentation")

data_augmentation = get_data_augmentation(seed=SEEDS[2])

# Define a function to load and preprocess a single image for visualization
def load_and_preprocess_image(path, label=None):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize_with_pad(img, IMG_SIZE, IMG_SIZE)
    # No normalization here, keep original pixel values for display
    return img, label

# Get a random image path from the training set
rng = np.random.default_rng(seed=SEEDS[0])
random_index = rng.integers(0, len(train_labels_df) - 1)
random_image_id = train_labels_df.index[random_index]
random_image_path = f"{IMAGESDIR}/{random_image_id}.png"

# Load and preprocess the original image
original_image, _ = load_and_preprocess_image(random_image_path)

# Create a figure to display the images
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()

# Display the original image
axes[0].imshow(original_image.numpy().astype("uint8"))
axes[0].set_title("Original Image")
axes[0].axis("off")

# Display augmented images
for i in range(1, 8):
    augmented_image = data_augmentation(tf.expand_dims(original_image, 0), training=True)
    # Remove the batch dimension and convert to uint8 for display
    axes[i].imshow(augmented_image[0].numpy().astype("uint8"))
    axes[i].set_title(f"Augmented {i}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
def build_custom_cnn(input_shape=(224, 224, 3), num_classes=5):
    model = keras.models.Sequential()

    # Input
    model.add(keras.layers.Input(shape=input_shape))

    # Block 1
    model.add(keras.layers.Conv2D(32, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.Conv2D(32, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.MaxPooling2D((2, 2)))

    # Block 2
    model.add(keras.layers.Conv2D(64, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.Conv2D(64, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.MaxPooling2D((2, 2)))

    # Block 3
    model.add(keras.layers.Conv2D(128, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.Conv2D(128, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.MaxPooling2D((2, 2)))

    # Block 4
    model.add(keras.layers.Conv2D(256, (3, 3), padding='same'))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.MaxPooling2D((2, 2))) # Added a conv layer here to follow the pattern

    # Classifier Head
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(256))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.ReLU())
    model.add(keras.layers.Dropout(0.5))

    # Output Layer
    model.add(keras.layers.Dense(num_classes, activation='softmax'))

    return model

# %%
# Train/validation split
image_paths = train_labels_df.index.map(lambda x: f"{IMAGESDIR}/{x}.png").to_list()
diagnostics = train_labels_df['diagnosis'].to_list()
train_paths, val_paths, train_labels, val_labels = train_test_split(
    image_paths, diagnostics, test_size=VAL_PERCENT, random_state=TRAIN_VAL_SPLIT_SEED, stratify=diagnostics
)

# Experiment function
def run_experiment(seed):
    print(f"\n{'='*60}")
    print(f"STARTING RUN WITH SEED: {seed}")
    print(f"{'='*60}")

    # Set all seeds for full reproducibility
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    AUTOTUNE = tf.data.AUTOTUNE

    data_augmentation = get_data_augmentation(seed=seed)

    # Apply augmentations and final transformations
    def augment_and_normalize(image, label):
        image = data_augmentation(image, training=True)
        image = image / 255.0
        return image, label

    # Prepare training data
    print("\nBuilding training dataset...")
    train_ds = (
        tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
        .map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
        .cache()
        .shuffle(buffer_size=len(train_paths), seed=seed)
        .map(augment_and_normalize)
        .batch(BATCH_SIZE)
        .prefetch(AUTOTUNE)
    )
    print("Training dataset is ready!")

    # Prepare validation data
    print("\nBuilding validation dataset...")
    validation_ds = (
        tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
        .map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)
        .map(lambda img, lbl: (img / 255.0, lbl)) # Just normalize, no augmentation
        .cache()
        .batch(BATCH_SIZE)
        .prefetch(AUTOTUNE)
    )
    print("Validation dataset is ready!")

    # Compile model
    model = build_custom_cnn()
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Callbacks/Monitoring
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)
    model_checkpoint_path = f'best_model_seed_{seed}.keras'
    model_checkpoint = keras.callbacks.ModelCheckpoint(
        filepath=model_checkpoint_path, save_best_only=True, monitor='val_loss', mode='min'
    )

    # Training
    print(f"\n--- Training model for seed {seed} ---")
    history = model.fit(
        train_ds,
        epochs=NUM_EPOCHS,
        validation_data=validation_ds,
        callbacks=[early_stopping, model_checkpoint],
        verbose=1
    )

    # Evaluation
    print(f"\n--- Evaluating best model for seed {seed} from {model_checkpoint_path} ---")
    best_model = keras.models.load_model(model_checkpoint_path)
    print("Generating predictions on the validation set...")
    # Get the raw probability predictions
    raw_predictions = best_model.predict(validation_ds)
    # Convert probabilities to class labels (0, 1, 2, 3, 4)
    y_pred = np.argmax(raw_predictions, axis=1)
    # Extract the true labels from the validation dataset
    y_true = np.concatenate([y for x, y in validation_ds], axis=0)
    print("Calculating evaluation metrics...")

    # Cohen's Kappa (Quadratic Weighted)
    kappa = sklearn.metrics.cohen_kappa_score(y_true, y_pred, weights='quadratic')

    # F1, Precision, Recall
    # Using output_dict=True to easily access the values
    report = sklearn.metrics.classification_report(y_true, y_pred, output_dict=True)
    # We'll use the weighted average, which accounts for class imbalance
    precision = report['weighted avg']['precision']
    recall = report['weighted avg']['recall']
    f1_score = report['weighted avg']['f1-score']
    auc_score = sklearn.metrics.roc_auc_score(y_true, raw_predictions, multi_class='ovr')
    auc_by_class = sklearn.metrics.roc_auc_score(y_true, raw_predictions, multi_class='ovr', average=None)

    # Basic loss and accuracy from model.evaluate
    final_scores = best_model.evaluate(validation_ds, verbose=0)

    print(f"\nResults for Seed {seed}:")
    print(f"  - Validation Loss: {final_scores[0]:.4f}")
    print(f"  - Validation Accuracy: {final_scores[1]:.4f}")
    print(f"  - Quadratic Weighted Kappa: {kappa:.4f}")
    print(f"  - Weighted F1-Score: {f1_score:.4f}")
    print(f"  - Weighted Precision: {precision:.4f}")
    print(f"  - Weighted Recall: {recall:.4f}")
    print(f"  - AUC Score (ovr): {auc_score:.4f}")
    print(f"  - AUC Score by Class: {auc_by_class}")

    return {
        'seed': seed,
        'history': history.history,
        'val_loss': final_scores[0],
        'val_accuracy': final_scores[1],
        'kappa': kappa,
        'f1_score': f1_score,
        'precision': precision,
        'recall': recall,
        'auc_score': auc_score,
        'auc_by_class': auc_by_class,
        'y_true': y_true,
        'raw_predictions': raw_predictions,
        'full_report': report
    }


all_results = []
for seed_value in SEEDS:
    result = run_experiment(seed_value)
    all_results.append(result)

print(f"\n{'='*60}")
print("FINAL RESULTS ACROSS ALL RUNS")
print(f"{'='*60}")
print("Parameters used:")
print(f"  - Learning Rate: {LEARNING_RATE}")
print(f"  - Epochs: Up to {NUM_EPOCHS} (with Early Stopping patience={PATIENCE})")
print(f"  - Batch Size: {BATCH_SIZE}")
print(f"  - Seeds: {SEEDS}")

results_df = pd.DataFrame(all_results)
metric_columns = ['seed', 'val_loss', 'val_accuracy', 'kappa', 'f1_score', 'precision', 'recall']
print("\n--- Per-run Metrics ---")
print(results_df[metric_columns].round(4))

print("\n--- Summary Statistics (Média e Desvio-Padrão) ---")
summary_cols = ['val_loss', 'val_accuracy', 'kappa', 'f1_score', 'precision', 'recall']
summary = results_df[summary_cols].agg(['mean', 'std'])
print(summary.round(4))


# Gráficos de acurácia e loss
print("\n== Generating Plots ==")
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
fig.suptitle('Training and Validation Metrics Across Runs', fontsize=16)

# Plot Training & Validation Accuracy for one representative run (e.g., the first one)
axes[0, 0].plot(all_results[0]['history']['accuracy'], label='Training Accuracy')
axes[0, 0].plot(all_results[0]['history']['val_accuracy'], label='Validation Accuracy')
axes[0, 0].set_title(f'Accuracy (Run with Seed {all_results[0]["seed"]})')
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Accuracy')
axes[0, 0].legend()
axes[0, 0].grid(True)

# Plot Training & Validation Loss for one representative run
axes[0, 1].plot(all_results[0]['history']['loss'], label='Training Loss')
axes[0, 1].plot(all_results[0]['history']['val_loss'], label='Validation Loss')
axes[0, 1].set_title(f'Loss (Run with Seed {all_results[0]["seed"]})')
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Loss')
axes[0, 1].legend()
axes[0, 1].grid(True)

# Plot Validation Accuracy across all runs to show stability
for result in all_results:
    axes[1, 0].plot(result['history']['val_accuracy'], 'o--', alpha=0.7, label=f"Seed {result['seed']}")
axes[1, 0].set_title('Validation Accuracy Comparison')
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].legend()
axes[1, 0].grid(True)

# Plot Validation Loss across all runs to show stability
for result in all_results:
    axes[1, 1].plot(result['history']['val_loss'], 'o--', alpha=0.7, label=f"Seed {result['seed']}")
axes[1, 1].set_title('Validation Loss Comparison')
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].legend()
axes[1, 1].grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# ROC Curves
roc_fig, roc_axs = plt.subplots(3, 1)
for result in all_results:
    y_true = result['y_true']
    raw_predictions = result['raw_predictions']
    y_pred = np.argmax(raw_predictions, axis=1)
    # --- Plot 1: Multi-Class ROC Curves ---
    # Setup for the plot
    fig, ax = plt.subplots(1, 1, figsize=(10, 8))

    # Store the FPR, TPR, and AUC for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # Calculate the ROC curve and AUC for each class (One-vs-Rest)
    for i in range(NUM_CLASSES):
        # Create binary true labels for the current class
        y_true_class = (y_true == i).astype(int)
        # Get the model's scores for the current class
        y_score_class = raw_predictions[:, i]

        fpr[i], tpr[i], _ = sklearn.metrics.roc_curve(y_true_class, y_score_class)
        roc_auc[i] = sklearn.metrics.auc(fpr[i], tpr[i])

    # Plot each class's ROC curve
    for i in range(NUM_CLASSES):
        ax.plot(fpr[i], tpr[i], lw=2,
                label=f'ROC curve of class {i} (area = {roc_auc[i]:0.2f})')

    # Plot the "no-skill" line
    ax.plot([0, 1], [0, 1], 'k--', lw=2, label='No-Skill Line')

    # Final plot settings
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Multi-Class Receiver Operating Characteristic (ROC) Curves')
    ax.legend(loc="lower right")
    ax.grid(True)
    plt.show()


    # --- Plot 2: Confusion Matrix Heatmap ---

    # Calculate the confusion matrix
    cm = sklearn.metrics.confusion_matrix(y_true, y_pred)

    # Create a figure for the heatmap
    plt.figure(figsize=(10, 8))

    # Use seaborn to create a heatmap
    sns.heatmap(cm,
                annot=True,     # Show the numbers in each cell
                fmt='d',        # Format the numbers as integers
                cmap='Blues',   # Color scheme
                xticklabels=range(NUM_CLASSES),
                yticklabels=range(NUM_CLASSES))

    plt.title('Confusion Matrix Heatmap')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()
# Out:
# ============================================================
# STARTING RUN WITH SEED: 564258
# ============================================================
#
# Building training dataset...
# Training dataset is ready!
#
# Building validation dataset...
# Validation dataset is ready!
#
# --- Training model for seed 564258 ---
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 269s 1s/step - accuracy: 0.5661 - loss: 1.2944 - val_accuracy: 0.4932 - val_loss: 1.2586
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 522ms/step - accuracy: 0.6395 - loss: 1.0558 - val_accuracy: 0.4932 - val_loss: 1.7407
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 516ms/step - accuracy: 0.6736 - loss: 0.9260 - val_accuracy: 0.4932 - val_loss: 1.8045
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.6881 - loss: 0.8828 - val_accuracy: 0.4932 - val_loss: 1.4154
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 516ms/step - accuracy: 0.6840 - loss: 0.9047 - val_accuracy: 0.4932 - val_loss: 1.6660
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.7000 - loss: 0.8633 - val_accuracy: 0.5648 - val_loss: 1.0889
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 944ms/step - accuracy: 0.6980 - loss: 0.8351 - val_accuracy: 0.6809 - val_loss: 0.8667
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 945ms/step - accuracy: 0.6921 - loss: 0.8452 - val_accuracy: 0.7133 - val_loss: 0.8344
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 946ms/step - accuracy: 0.6959 - loss: 0.8425 - val_accuracy: 0.7014 - val_loss: 0.8213
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 521ms/step - accuracy: 0.7097 - loss: 0.8180 - val_accuracy: 0.6877 - val_loss: 0.8911
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 62s 846ms/step - accuracy: 0.7212 - loss: 0.7864 - val_accuracy: 0.7133 - val_loss: 0.8162
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 526ms/step - accuracy: 0.6836 - loss: 0.8315 - val_accuracy: 0.6980 - val_loss: 0.8764
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.7141 - loss: 0.7896 - val_accuracy: 0.7150 - val_loss: 0.7812
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 45s 517ms/step - accuracy: 0.7126 - loss: 0.7862 - val_accuracy: 0.7150 - val_loss: 0.8339
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.7300 - loss: 0.7790 - val_accuracy: 0.7133 - val_loss: 0.8253
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.7219 - loss: 0.7662 - val_accuracy: 0.7082 - val_loss: 0.8094
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 512ms/step - accuracy: 0.7395 - loss: 0.7266 - val_accuracy: 0.7099 - val_loss: 0.8592
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.7323 - loss: 0.7361 - val_accuracy: 0.7457 - val_loss: 0.6918
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.7480 - loss: 0.6759 - val_accuracy: 0.7287 - val_loss: 0.6856
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 514ms/step - accuracy: 0.7312 - loss: 0.7301 - val_accuracy: 0.7645 - val_loss: 0.6926
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - accuracy: 0.7663 - loss: 0.6605 - val_accuracy: 0.7253 - val_loss: 0.6858
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.7461 - loss: 0.6927 - val_accuracy: 0.7014 - val_loss: 0.8649
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 71s 935ms/step - accuracy: 0.7698 - loss: 0.6065 - val_accuracy: 0.7850 - val_loss: 0.6259
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 51s 516ms/step - accuracy: 0.7553 - loss: 0.6426 - val_accuracy: 0.6945 - val_loss: 0.8848
# Epoch 25/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 522ms/step - accuracy: 0.7749 - loss: 0.5901 - val_accuracy: 0.7645 - val_loss: 0.6421
# Epoch 26/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.7843 - loss: 0.5836 - val_accuracy: 0.7509 - val_loss: 0.6452
# Epoch 27/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 517ms/step - accuracy: 0.7925 - loss: 0.5574 - val_accuracy: 0.7730 - val_loss: 0.6958
# Epoch 28/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.7937 - loss: 0.5273 - val_accuracy: 0.7696 - val_loss: 0.6611
# Epoch 29/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.7655 - loss: 0.5888 - val_accuracy: 0.7679 - val_loss: 0.7407
# Epoch 30/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.7857 - loss: 0.5398 - val_accuracy: 0.6502 - val_loss: 0.8703
# Epoch 31/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 522ms/step - accuracy: 0.8002 - loss: 0.5374 - val_accuracy: 0.7389 - val_loss: 0.7051
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 23.
#
# --- Evaluating best model for seed 564258 from best_model_seed_564258.keras ---
# Generating predictions on the validation set...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step
# Calculating evaluation metrics...
#
# Results for Seed 564258:
#   - Validation Loss: 0.6259
#   - Validation Accuracy: 0.7850
#   - Quadratic Weighted Kappa: 0.8135
#   - Weighted F1-Score: 0.7657
#   - Weighted Precision: 0.7750
#   - Weighted Recall: 0.7850
#   - AUC Score (ovr): 0.9048
#   - AUC Score by Class: [0.99186793 0.90702087 0.89878961 0.87744842 0.84889275]
#
# ============================================================
# STARTING RUN WITH SEED: 564307
# ============================================================
#
# Building training dataset...
# Training dataset is ready!
#
# Building validation dataset...
# Validation dataset is ready!
#
# --- Training model for seed 564307 ---
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 272s 2s/step - accuracy: 0.5018 - loss: 1.4617 - val_accuracy: 0.4932 - val_loss: 1.2688
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 70s 948ms/step - accuracy: 0.6322 - loss: 1.0640 - val_accuracy: 0.5290 - val_loss: 1.2175
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 74s 1s/step - accuracy: 0.6571 - loss: 0.9961 - val_accuracy: 0.6399 - val_loss: 1.1525
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6759 - loss: 0.8771 - val_accuracy: 0.5853 - val_loss: 1.1478
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6910 - loss: 0.8912 - val_accuracy: 0.6809 - val_loss: 1.0106
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 132s 972ms/step - accuracy: 0.6829 - loss: 0.8864 - val_accuracy: 0.6433 - val_loss: 0.9736
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6972 - loss: 0.8511 - val_accuracy: 0.6980 - val_loss: 0.8137
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.6871 - loss: 0.8513 - val_accuracy: 0.6843 - val_loss: 0.8511
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.7097 - loss: 0.7877 - val_accuracy: 0.6706 - val_loss: 0.8796
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 513ms/step - accuracy: 0.7179 - loss: 0.7922 - val_accuracy: 0.6792 - val_loss: 0.9335
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.7186 - loss: 0.7766 - val_accuracy: 0.7235 - val_loss: 0.7752
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.7236 - loss: 0.7753 - val_accuracy: 0.7406 - val_loss: 0.7227
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 518ms/step - accuracy: 0.7363 - loss: 0.7638 - val_accuracy: 0.7218 - val_loss: 0.7707
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.7389 - loss: 0.7432 - val_accuracy: 0.7338 - val_loss: 0.7395
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.7300 - loss: 0.7027 - val_accuracy: 0.7662 - val_loss: 0.7068
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 515ms/step - accuracy: 0.7532 - loss: 0.6735 - val_accuracy: 0.6758 - val_loss: 0.9641
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - accuracy: 0.7555 - loss: 0.6683 - val_accuracy: 0.7338 - val_loss: 0.7536
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.7564 - loss: 0.6504 - val_accuracy: 0.7611 - val_loss: 0.6777
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 527ms/step - accuracy: 0.7683 - loss: 0.6318 - val_accuracy: 0.7662 - val_loss: 0.6891
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 516ms/step - accuracy: 0.7601 - loss: 0.6524 - val_accuracy: 0.7184 - val_loss: 0.7482
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7718 - loss: 0.6203 - val_accuracy: 0.7577 - val_loss: 0.6588
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 93s 525ms/step - accuracy: 0.7752 - loss: 0.5745 - val_accuracy: 0.7526 - val_loss: 0.7259
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 514ms/step - accuracy: 0.7624 - loss: 0.6460 - val_accuracy: 0.7543 - val_loss: 0.6917
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 42s 525ms/step - accuracy: 0.7949 - loss: 0.5635 - val_accuracy: 0.7491 - val_loss: 0.6873
# Epoch 25/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 516ms/step - accuracy: 0.7788 - loss: 0.5787 - val_accuracy: 0.7201 - val_loss: 0.7475
# Epoch 26/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7818 - loss: 0.5990 - val_accuracy: 0.7440 - val_loss: 0.6467
# Epoch 27/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7874 - loss: 0.5748 - val_accuracy: 0.7713 - val_loss: 0.6848
# Epoch 28/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.7683 - loss: 0.6253 - val_accuracy: 0.7679 - val_loss: 0.6363
# Epoch 29/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7827 - loss: 0.5640 - val_accuracy: 0.7611 - val_loss: 0.7267
# Epoch 30/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 42s 528ms/step - accuracy: 0.8137 - loss: 0.4991 - val_accuracy: 0.7372 - val_loss: 0.7426
# Epoch 31/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 521ms/step - accuracy: 0.7944 - loss: 0.5389 - val_accuracy: 0.7747 - val_loss: 0.7100
# Epoch 32/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.7845 - loss: 0.5747 - val_accuracy: 0.7696 - val_loss: 0.6324
# Epoch 33/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8008 - loss: 0.5119 - val_accuracy: 0.7935 - val_loss: 0.6026
# Epoch 34/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 521ms/step - accuracy: 0.8184 - loss: 0.4776 - val_accuracy: 0.7201 - val_loss: 0.6881
# Epoch 35/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 529ms/step - accuracy: 0.8300 - loss: 0.4735 - val_accuracy: 0.7526 - val_loss: 0.7614
# Epoch 36/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 519ms/step - accuracy: 0.8358 - loss: 0.4526 - val_accuracy: 0.7645 - val_loss: 0.6566
# Epoch 37/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 518ms/step - accuracy: 0.8315 - loss: 0.4563 - val_accuracy: 0.7253 - val_loss: 0.8030
# Epoch 38/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.8442 - loss: 0.4035 - val_accuracy: 0.7747 - val_loss: 0.7348
# Epoch 39/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 519ms/step - accuracy: 0.8237 - loss: 0.4460 - val_accuracy: 0.7696 - val_loss: 0.6302
# Epoch 40/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.8296 - loss: 0.4219 - val_accuracy: 0.7816 - val_loss: 0.6535
# Epoch 41/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 533ms/step - accuracy: 0.8449 - loss: 0.4097 - val_accuracy: 0.7474 - val_loss: 0.7246
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# --- Evaluating best model for seed 564307 from best_model_seed_564307.keras ---
# Generating predictions on the validation set...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step
# Calculating evaluation metrics...
#
# Results for Seed 564307:
#   - Validation Loss: 0.6026
#   - Validation Accuracy: 0.7935
#   - Quadratic Weighted Kappa: 0.8390
#   - Weighted F1-Score: 0.7846
#   - Weighted Precision: 0.7872
#   - Weighted Recall: 0.7935
#   - AUC Score (ovr): 0.9084
#   - AUC Score by Class: [0.99655144 0.90547712 0.90371919 0.87866899 0.85757707]
#
# ============================================================
# STARTING RUN WITH SEED: 564322
# ============================================================
#
# Building training dataset...
# Training dataset is ready!
#
# Building validation dataset...
# Validation dataset is ready!
#
# --- Training model for seed 564322 ---
# Epoch 1/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.5351 - loss: 1.3198 - val_accuracy: 0.4932 - val_loss: 1.3433
# Epoch 2/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.6301 - loss: 1.0794 - val_accuracy: 0.4932 - val_loss: 1.3285
# Epoch 3/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.6795 - loss: 0.9105 - val_accuracy: 0.5427 - val_loss: 1.2464
# Epoch 4/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 44s 521ms/step - accuracy: 0.6821 - loss: 0.9155 - val_accuracy: 0.3038 - val_loss: 1.4245
# Epoch 5/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6845 - loss: 0.8911 - val_accuracy: 0.6007 - val_loss: 1.0632
# Epoch 6/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.6722 - loss: 0.9164 - val_accuracy: 0.6758 - val_loss: 1.0303
# Epoch 7/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7061 - loss: 0.8251 - val_accuracy: 0.6638 - val_loss: 1.0458
# Epoch 8/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7116 - loss: 0.8230 - val_accuracy: 0.6877 - val_loss: 0.8734
# Epoch 9/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 521ms/step - accuracy: 0.7069 - loss: 0.8119 - val_accuracy: 0.6877 - val_loss: 0.8942
# Epoch 10/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7165 - loss: 0.7722 - val_accuracy: 0.6877 - val_loss: 0.8807
# Epoch 11/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.7094 - loss: 0.8029 - val_accuracy: 0.7031 - val_loss: 0.8424
# Epoch 12/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7086 - loss: 0.7828 - val_accuracy: 0.5922 - val_loss: 1.2537
# Epoch 13/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.7335 - loss: 0.7314 - val_accuracy: 0.7048 - val_loss: 0.8251
# Epoch 14/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 131s 1s/step - accuracy: 0.7160 - loss: 0.7414 - val_accuracy: 0.7014 - val_loss: 0.8190
# Epoch 15/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.7494 - loss: 0.6960 - val_accuracy: 0.7270 - val_loss: 0.7321
# Epoch 16/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 533ms/step - accuracy: 0.7610 - loss: 0.6450 - val_accuracy: 0.7133 - val_loss: 0.7461
# Epoch 17/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7387 - loss: 0.6954 - val_accuracy: 0.7338 - val_loss: 0.7086
# Epoch 18/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 521ms/step - accuracy: 0.7442 - loss: 0.6615 - val_accuracy: 0.7150 - val_loss: 0.7131
# Epoch 19/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 42s 538ms/step - accuracy: 0.7570 - loss: 0.6499 - val_accuracy: 0.7389 - val_loss: 0.7604
# Epoch 20/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 40s 522ms/step - accuracy: 0.7572 - loss: 0.6461 - val_accuracy: 0.7287 - val_loss: 0.7269
# Epoch 21/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.7729 - loss: 0.6083 - val_accuracy: 0.7389 - val_loss: 0.6832
# Epoch 22/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 89s 527ms/step - accuracy: 0.7661 - loss: 0.6204 - val_accuracy: 0.7338 - val_loss: 0.7660
# Epoch 23/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.7584 - loss: 0.6374 - val_accuracy: 0.7474 - val_loss: 0.7302
# Epoch 24/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7769 - loss: 0.6063 - val_accuracy: 0.7543 - val_loss: 0.6457
# Epoch 25/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 90s 522ms/step - accuracy: 0.7675 - loss: 0.5936 - val_accuracy: 0.7048 - val_loss: 0.7685
# Epoch 26/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.7825 - loss: 0.5739 - val_accuracy: 0.7509 - val_loss: 0.6879
# Epoch 27/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.7838 - loss: 0.5451 - val_accuracy: 0.7116 - val_loss: 0.7770
# Epoch 28/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 516ms/step - accuracy: 0.7971 - loss: 0.5015 - val_accuracy: 0.6843 - val_loss: 0.8945
# Epoch 29/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.7947 - loss: 0.5482 - val_accuracy: 0.7253 - val_loss: 0.7313
# Epoch 30/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8168 - loss: 0.4879 - val_accuracy: 0.7611 - val_loss: 0.6402
# Epoch 31/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 92s 521ms/step - accuracy: 0.8117 - loss: 0.4892 - val_accuracy: 0.7406 - val_loss: 0.7259
# Epoch 32/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 518ms/step - accuracy: 0.8092 - loss: 0.5009 - val_accuracy: 0.7713 - val_loss: 0.6765
# Epoch 33/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 523ms/step - accuracy: 0.8162 - loss: 0.4612 - val_accuracy: 0.7730 - val_loss: 0.6798
# Epoch 34/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 517ms/step - accuracy: 0.8140 - loss: 0.4542 - val_accuracy: 0.7526 - val_loss: 0.6715
# Epoch 35/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 522ms/step - accuracy: 0.8345 - loss: 0.4616 - val_accuracy: 0.7543 - val_loss: 0.6848
# Epoch 36/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 39s 520ms/step - accuracy: 0.8266 - loss: 0.4478 - val_accuracy: 0.7611 - val_loss: 0.7833
# Epoch 37/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 41s 520ms/step - accuracy: 0.8472 - loss: 0.4325 - val_accuracy: 0.7184 - val_loss: 0.7479
# Epoch 38/100
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 38s 516ms/step - accuracy: 0.8462 - loss: 0.4148 - val_accuracy: 0.7509 - val_loss: 0.9681
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 30.
#
# --- Evaluating best model for seed 564322 from best_model_seed_564322.keras ---
# Generating predictions on the validation set...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step
# Calculating evaluation metrics...
#
# Results for Seed 564322:
#   - Validation Loss: 0.6402
#   - Validation Accuracy: 0.7611
#   - Quadratic Weighted Kappa: 0.7878
#   - Weighted F1-Score: 0.7322
#   - Weighted Precision: 0.7556
#   - Weighted Recall: 0.7611
#   - AUC Score (ovr): 0.9010
#   - AUC Score by Class: [0.99163492 0.87768951 0.8951071  0.87320546 0.86720878]
#
# ============================================================
# FINAL RESULTS ACROSS ALL RUNS
# ============================================================
# Parameters used:
#   - Learning Rate: 0.001
#   - Epochs: Up to 100 (with Early Stopping patience=8)
#   - Batch Size: 32
#   - Seeds: [564258, 564307, 564322]
#
# --- Per-run Metrics ---
#      seed  val_loss  val_accuracy   kappa  f1_score  precision  recall
# 0  564258    0.6259        0.7850  0.8135    0.7657     0.7750  0.7850
# 1  564307    0.6026        0.7935  0.8390    0.7846     0.7872  0.7935
# 2  564322    0.6402        0.7611  0.7878    0.7322     0.7556  0.7611
#
# --- Summary Statistics (Média e Desvio-Padrão) ---
#       val_loss  val_accuracy   kappa  f1_score  precision  recall
# mean    0.6229        0.7799  0.8134    0.7609     0.7726  0.7799
# std     0.0190        0.0168  0.0256    0.0265     0.0160  0.0168
#
# == Generating Plots ==

# %%
for result in all_results:
    seed = result['seed']
    y_true = result['y_true']
    raw_predictions = result['raw_predictions']
    y_pred = np.argmax(raw_predictions, axis=1)

    print(f"--- Results for Seed: {seed} ---")

    # Use classification_report to get detailed metrics
    # Set output_dict=True to get a dictionary that's easy to work with
    report = sklearn.metrics.classification_report(y_true, y_pred, output_dict=True, zero_division=0)

    # Create a list to hold the data for our table
    class_metrics = []

    # Iterate through each class found in the report
    # We skip the summary keys like 'accuracy', 'macro avg', 'weighted avg'
    for class_label, metrics in report.items():
        if class_label.isdigit(): # Check if the key is a class label (e.g., '0', '1', ...)
            class_metrics.append({
                'Class': int(class_label),
                'Precision': metrics['precision'],
                'Recall': metrics['recall'],
                'F1-Score': metrics['f1-score'],
                'Support': metrics['support'] # Number of true instances in this class
            })

    # Convert the list of dictionaries to a pandas DataFrame for nice printing
    metrics_df = pd.DataFrame(class_metrics).set_index('Class')

    # Print the DataFrame
    print(metrics_df.round(3)) # Round to 3 decimal places for readability
    print("\n" + "-"*35 + "\n")
# Out:
# --- Results for Seed: 564258 ---
#        Precision  Recall  F1-Score  Support
# Class
# 0          0.950   0.983     0.966    289.0
# 1          0.735   0.424     0.538     59.0
# 2          0.624   0.831     0.713    160.0
# 3          0.545   0.194     0.286     31.0
# 4          0.414   0.255     0.316     47.0
#
# -----------------------------------
#
# --- Results for Seed: 564307 ---
#        Precision  Recall  F1-Score  Support
# Class
# 0          0.950   0.990     0.969    289.0
# 1          0.735   0.424     0.538     59.0
# 2          0.663   0.762     0.709    160.0
# 3          0.480   0.387     0.429     31.0
# 4          0.476   0.426     0.449     47.0
#
# -----------------------------------
#
# --- Results for Seed: 564322 ---
#        Precision  Recall  F1-Score  Support
# Class
# 0          0.953   0.972     0.962    289.0
# 1          0.581   0.305     0.400     59.0
# 2          0.584   0.844     0.691    160.0
# 3          0.333   0.226     0.269     31.0
# 4          0.625   0.106     0.182     47.0
#
# -----------------------------------

# %%
model_564258 = keras.models.load_model('best_model_seed_564258.keras')
model_564307 = keras.models.load_model('best_model_seed_564307.keras')
model_564322 = keras.models.load_model('best_model_seed_564322.keras')

test_image_paths = test_labels_df.index.map(lambda x: f"{IMAGESDIR}/{x}.png").to_list()
test_labels = test_labels_df['diagnosis'].to_list()

test_ds = (
    tf.data.Dataset.from_tensor_slices((test_image_paths, test_labels))
    .map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    .map(lambda img, lbl: (img / 255.0, lbl)) # Just normalize, no augmentation
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
test_ds = (
    tf.data.Dataset.from_tensor_slices((test_image_paths, test_labels))
    .map(load_and_preprocess_image, num_parallel_calls=tf.data.AUTOTUNE)
    .map(lambda img, lbl: (img / 255.0, lbl)) # Just normalize, no augmentation
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
def evaluate(model):
    print("Generating predictions on the test set...")
    # Get the raw probability predictions
    raw_predictions = model.predict(test_ds)
    y_pred = np.argmax(raw_predictions, axis=1)
    y_true = np.concatenate([y for x, y in test_ds], axis=0)

    print("Calculating evaluation metrics...")
    print("Cohen's Kappa (Quadratic Weighted):")
    kappa = sklearn.metrics.cohen_kappa_score(y_true, y_pred, weights='quadratic')
    print(kappa)
    print("Classification Report:")
    print(sklearn.metrics.classification_report(y_true, y_pred))
    print("Confusion Matrix:")
    print(sklearn.metrics.confusion_matrix(y_true, y_pred))
    print("Basic loss and accuracy from model.evaluate:")
    final_scores = model.evaluate(test_ds, verbose=0)
    print(final_scores)
    print("AUC Score:")
    print(sklearn.metrics.roc_auc_score(y_true, raw_predictions, multi_class='ovr'))

    # plot ROC curve
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(NUM_CLASSES):
        y_true_class = (y_true == i).astype(int)
        y_score_class = raw_predictions[:, i]
        fpr[i], tpr[i], _ = sklearn.metrics.roc_curve(y_true_class, y_score_class)
        roc_auc[i] = sklearn.metrics.auc(fpr[i], tpr[i])

        # Plot each class's ROC curve
        plt.plot(fpr[i], tpr[i], lw=2,
                label=f'ROC curve of class {i} (area = {roc_auc[i]:0.2f})')

    # Plot the "no-skill" line
    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='No-Skill Line')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-Class Receiver Operating Characteristic (ROC) Curves')
    plt.legend(loc="lower right")
    plt.grid(True)
    plt.show()

    # plot the confusion matrix

    cm = sklearn.metrics.confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm
                , annot=True
                , fmt='d'
                , cmap='Blues'
                , xticklabels=range(NUM_CLASSES)
                , yticklabels=range(NUM_CLASSES))

# %%
evaluate(model_564258)
# Out:
# Generating predictions on the test set...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step
# Calculating evaluation metrics...
# Cohen's Kappa (Quadratic Weighted):
# 0.8132796024471217
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       361
#            1       0.56      0.36      0.44        74
#            2       0.64      0.84      0.73       200
#            3       0.59      0.33      0.43        39
#            4       0.47      0.31      0.37        59
#
#     accuracy                           0.78       733
#    macro avg       0.64      0.56      0.58       733
# weighted avg       0.77      0.78      0.76       733
#
# Confusion Matrix:
# [[343   9   9   0   0]
#  [  6  27  37   1   3]
#  [ 10   6 169   6   9]
#  [  1   1  16  13   8]
#  [  0   5  34   2  18]]
# Basic loss and accuracy from model.evaluate:
# [0.6372520923614502, 0.7776262164115906]
# AUC Score:
# 0.9160204002532322

# %%
evaluate(model_564307)
# Out:
# Generating predictions on the test set...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step
# Calculating evaluation metrics...
# Cohen's Kappa (Quadratic Weighted):
# 0.806552834309396
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       361
#            1       0.59      0.41      0.48        74
#            2       0.67      0.74      0.70       200
#            3       0.42      0.38      0.40        39
#            4       0.42      0.37      0.39        59
#
#     accuracy                           0.77       733
#    macro avg       0.61      0.57      0.59       733
# weighted avg       0.76      0.77      0.76       733
#
# Confusion Matrix:
# [[347   6   6   0   2]
#  [  9  30  30   2   3]
#  [  9  12 149  11  19]
#  [  2   1  14  15   7]
#  [  2   2  25   8  22]]
# Basic loss and accuracy from model.evaluate:
# [0.6465259790420532, 0.7680764198303223]
# AUC Score:
# 0.9085830545070387

# %%
evaluate(model_564322)
# Out:
# Generating predictions on the test set...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step
# Calculating evaluation metrics...
# Cohen's Kappa (Quadratic Weighted):
# 0.799486759286694
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       361
#            1       0.53      0.31      0.39        74
#            2       0.60      0.85      0.71       200
#            3       0.46      0.41      0.43        39
#            4       0.62      0.17      0.27        59
#
#     accuracy                           0.77       733
#    macro avg       0.64      0.54      0.55       733
# weighted avg       0.77      0.77      0.75       733
#
# Confusion Matrix:
# [[341   6  13   0   1]
#  [  6  23  40   4   1]
#  [  9   9 171   9   2]
#  [  0   0  21  16   2]
#  [  0   5  38   6  10]]
# Basic loss and accuracy from model.evaluate:
# [0.6880271434783936, 0.7653478980064392]
# AUC Score:
# 0.9005637463544819
